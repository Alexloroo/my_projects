# %% [markdown]
# # Project Description
#
# This code participated in **"KBTU Data Science Challenge 2025"** and won the **first** place.
#
# The data set was provided by the organizers and is based on real academic analytics. All data is taken from **kaggle**.
#
# *Author: Alexey V.*
#
#
# # Task description
#
# ## Goal
#
# The goal of this project is to build a regression model that can **predict students' final math scores** based on various characteristics, including:
#
# * **Demographic data** (gender, education of parents, type of school).
# * **Academic performance** (number of study hours, attendance, previous grades)
# * **Extracurricular activities**
#
# The task includes preprocessing functions, normalizing data, building a model using TensorFlow/Keras, training, evaluation, and creating a CSV file with predicted estimates.
#
#
# ## Columns
#
# **student\_id** — unique identifier of each student
#
# **gender** — 'Male' or 'Female'
#
# **age** — student’s age
#
# **study\_hours** — average daily study hours
#
# **attendance\_rate** — class attendance rate in %
#
# **previous\_scores** — previous academic performance
#
# **parental\_education** — level of parents' education
#
# **school\_type** — 'Public' or 'Private' school
#
# **extracurricular** — level of participation in activities
#
# **final\_math\_score** — actual target value (used only in training)
#
#
# ## Tasks
#
# * Data loading and preprocessing
# * Normalization of numerical characteristics
# * Training a neural network regression model
# * Performance assessment and visualization
# * Predicting the test suite and exporting to CSV
#
# # Table of Contents
#
# ### 1. Data download
# ### 2. Visualization and data analysis
# ### 3. Preparation and normalization of functions
# ### 4. Model building and training
# ### 5. Visual assessment of the model
# ### 6. Prediction based on test data and generation of the final response

# %% [markdown]
# # 1. Data download

# %%
import pandas as pd
import tensorflow as tf
import tensorflow.keras as ker
import tensorflow.keras.layers as layer
import numpy as np
import matplotlib.pyplot as plt


train = pd.read_csv('E:\\Alex\\Github\\my_projects\\test\\train.csv')
test = pd.read_csv('E:\\Alex\\Github\\my_projects\\test\\test.csv')
#train.head(5)
train.describe()
# Out:
#         student_id          age  study_hours  attendance_rate  \
# count  4000.000000  4000.000000  4000.000000      4000.000000
# mean   3000.500000    16.514500    10.823475        75.025200
# std    1154.844867     1.116737     5.157597        14.553043
# min    1001.000000    15.000000     2.000000        50.000000
# 25%    2000.750000    16.000000     6.400000        62.300000
# 50%    3000.500000    17.000000    10.700000        74.700000
# 75%    4000.250000    18.000000    15.200000        87.900000
# max    5000.000000    18.000000    20.000000       100.000000
#
#        previous_scores  extracurricular  final_math_score
# count      4000.000000      4000.000000       4000.000000
# mean         70.508950         2.022000         87.507875
# std          17.217398         1.417575         12.196231
# min          40.000000         0.000000         40.100000
# 25%          55.800000         1.000000         79.300000
# 50%          70.900000         2.000000         89.900000
# 75%          85.100000         3.000000        100.000000
# max         100.000000         4.000000        100.000000

# %% [markdown]
# # 2. Visualization and data analysis
# ### Based on the data analysis, we can see the main correlation of the final grade in mathematics with the number of study hours, previous grades and attendance level.

# %%
df = train.copy()
plt.figure(figsize=(5, 4))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
numerical = ['age', 'study_hours', 'attendance_rate', 'previous_scores', 'extracurricular']
for col in numerical:
    plt.figure()
    sns.regplot(data=df, x=col, y='final_math_score', line_kws={'color': 'red'})
    plt.title(f'Correlation between {col} and final score')
    plt.show()

# %% [markdown]
# # 3. Preparation and normalization of functions

# %%
gen = {'Male': 0, 'Female': 1}
train['gender'] = train['gender'].map(gen)



edu = {'High School': 0, 'Master’s': 1, 'Bachelor’s': 2}
train['parental_education'] = train['parental_education'].map(edu)


school = {'Public': 0, 'Private': 1}
train['school_type'] = train['school_type'].map(school)
#train.head()

# %%
student_id = train['student_id']
train = train.drop(columns='student_id')

# %%
train
# Out:
#       gender  age  study_hours  attendance_rate  previous_scores  \
# 0          0   17          9.1             68.7             70.0
# 1          1   17         10.5             66.6             84.8
# 2          0   17         17.4             58.8             73.8
# 3          0   17          8.1             80.4             45.0
# 4          0   18         17.7             73.8             51.1
# ...      ...  ...          ...              ...              ...
# 3995       1   18         11.3             71.2             43.6
# 3996       1   15          5.0             95.8             53.6
# 3997       1   16         19.6             74.9             55.6
# 3998       1   15          3.9             69.9             63.2
# 3999       1   18         18.8             87.5             88.2
#
#       parental_education  school_type  extracurricular  final_math_score
# 0                      2            1                3              86.2
# 1                      2            0                3              90.6
# 2                      0            1                3              94.1
# 3                      0            0                1              82.9
# 4                      1            0                2              98.6
# ...                  ...          ...              ...               ...
# 3995                   0            0                4              78.8
# 3996                   0            0                3              80.5
# 3997                   2            0                2              93.0
# 3998                   1            1                3              70.9
# 3999                   0            1                2             100.0
#
# [4000 rows x 9 columns]

# %%
# Преобразуем train_data в тензоры
train_data = tf.convert_to_tensor(train.values, dtype=tf.float32)

mean, variance = tf.nn.moments(train_data, axes=[0])
std = tf.sqrt(variance)

# Нормализуем данные
normalized_data = (train_data - mean) / std

normalized_array = normalized_data.numpy()
train = pd.DataFrame(normalized_array, columns=train.columns)
train
# Out:
#         gender       age  study_hours  attendance_rate  previous_scores  \
# 0    -1.003501  0.434803    -0.334204        -0.434686        -0.029563
# 1     0.996501  0.434803    -0.062726        -0.579004         0.830140
# 2    -1.003501  0.434803     1.275274        -1.115042         0.191172
# 3    -1.003501  0.434803    -0.528117         0.369370        -1.481764
# 4    -1.003501  1.330380     1.333448        -0.084200        -1.127427
# ...        ...       ...          ...              ...              ...
# 3995  0.996501  1.330380     0.092404        -0.262880        -1.563088
# 3996  0.996501 -1.356351    -1.129248         1.427701        -0.982207
# 3997  0.996501 -0.460774     1.701882        -0.008605        -0.866031
# 3998  0.996501 -1.356351    -1.342552        -0.352219        -0.424562
# 3999  0.996501  1.330380     1.546752         0.857302         1.027639
#
#       parental_education  school_type  extracurricular  final_math_score
# 0               1.260821     1.020205         0.689996         -0.107247
# 1               1.260821    -0.980197         0.689996          0.253565
# 2              -1.176136     1.020205         0.689996          0.540574
# 3              -1.176136    -0.980197        -0.721039         -0.377855
# 4               0.042342    -0.980197        -0.015521          0.909585
# ...                  ...          ...              ...               ...
# 3995           -1.176136    -0.980197         1.395514         -0.714065
# 3996           -1.176136    -0.980197         0.689996         -0.574661
# 3997            1.260821    -0.980197        -0.015521          0.450371
# 3998            0.042342     1.020205         0.689996         -1.361886
# 3999           -1.176136     1.020205        -0.015521          1.024389
#
# [4000 rows x 9 columns]

# %%
y = train['final_math_score']
x = train.drop(columns='final_math_score')
in_layer = len(train.columns) -1

# %%
# Сохраняем среднее и стандартное отклонение только по целевой переменной для последующей денормализации
target_mean = mean[-1].numpy()
target_std = std[-1].numpy()

# %% [markdown]
# # 4. Model building and training

# %%
batch = 32
epochs=100
data = tf.data.Dataset.from_tensor_slices((x.values, y.values)).shuffle(len(x))
train_size = int(len(x) * 0.8)
train_data = data.take(train_size).batch(batch)
val_data = data.skip(train_size).batch(batch)

model = tf.keras.Sequential([
  
    layer.Dense(512, activation='swish', input_shape=(in_layer,), kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    layer.BatchNormalization(),
    layer.Dropout(0.3),  

    layer.Dense(256, activation='swish',
                         kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    layer.BatchNormalization(),
    layer.Dropout(0.3),
    

    layer.Dense(128, activation='swish',
                         kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    layer.BatchNormalization(),
    layer.Dropout(0.3),
    

    layer.Dense(64, activation='swish'),
    layer.Dense(32, activation='swish'),
    layer.Dense(1, activation='linear'),
    layer.Lambda(lambda x: tf.minimum(x, 100))
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),  
    loss=tf.keras.losses.Huber(),
    metrics=['mae', 'mse']
)
# Out:
# e:\Alex\Anaconda\envs\tf_env\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:From e:\Alex\Anaconda\envs\tf_env\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, verbose=1),
    tf.keras.callbacks.ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)
]

history = model.fit(
    train_data,
    batch_size=batch,
    epochs=epochs,
    validation_data=val_data,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 5.2670 - mae: 0.6400 - mse: 0.7187 - val_loss: 4.2516 - val_mae: 0.7315 - val_mse: 0.7887 - learning_rate: 5.0000e-04
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7025 - mae: 0.4095 - mse: 0.2861 - val_loss: 2.9298 - val_mae: 0.6708 - val_mse: 0.7017 - learning_rate: 5.0000e-04
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4886 - mae: 0.3826 - mse: 0.2525 - val_loss: 1.9378 - val_mae: 0.6084 - val_mse: 0.5464 - learning_rate: 5.0000e-04
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6160 - mae: 0.3565 - mse: 0.2199 - val_loss: 1.2916 - val_mae: 0.5664 - val_mse: 0.5303 - learning_rate: 5.0000e-04
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0504 - mae: 0.3580 - mse: 0.2237 - val_loss: 0.8092 - val_mae: 0.4461 - val_mse: 0.3259 - learning_rate: 5.0000e-04
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6798 - mae: 0.3377 - mse: 0.1960 - val_loss: 0.5212 - val_mae: 0.3758 - val_mse: 0.2396 - learning_rate: 5.0000e-04
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4593 - mae: 0.3373 - mse: 0.1982 - val_loss: 0.3799 - val_mae: 0.3877 - val_mse: 0.2568 - learning_rate: 5.0000e-04
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.3280 - mae: 0.3358 - mse: 0.2015 - val_loss: 0.2718 - val_mae: 0.3582 - val_mse: 0.2203 - learning_rate: 5.0000e-04
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2377 - mae: 0.3176 - mse: 0.1823 - val_loss: 0.2000 - val_mae: 0.3302 - val_mse: 0.1817 - learning_rate: 5.0000e-04
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1907 - mae: 0.3206 - mse: 0.1843 - val_loss: 0.1726 - val_mae: 0.3449 - val_mse: 0.2014 - learning_rate: 5.0000e-04
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1609 - mae: 0.3290 - mse: 0.1882 - val_loss: 0.1251 - val_mae: 0.2851 - val_mse: 0.1434 - learning_rate: 5.0000e-04
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1496 - mae: 0.3359 - mse: 0.2021 - val_loss: 0.1323 - val_mae: 0.3218 - val_mse: 0.1891 - learning_rate: 5.0000e-04
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1241 - mae: 0.3166 - mse: 0.1753 - val_loss: 0.1265 - val_mae: 0.3378 - val_mse: 0.1944 - learning_rate: 5.0000e-04
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1204 - mae: 0.3194 - mse: 0.1835 - val_loss: 0.1025 - val_mae: 0.2962 - val_mse: 0.1568 - learning_rate: 5.0000e-04
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1103 - mae: 0.3119 - mse: 0.1740 - val_loss: 0.0858 - val_mae: 0.2825 - val_mse: 0.1265 - learning_rate: 5.0000e-04
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1094 - mae: 0.3175 - mse: 0.1757 - val_loss: 0.0923 - val_mae: 0.2899 - val_mse: 0.1444 - learning_rate: 5.0000e-04
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1130 - mae: 0.3220 - mse: 0.1902 - val_loss: 0.1065 - val_mae: 0.3192 - val_mse: 0.1804 - learning_rate: 5.0000e-04
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1072 - mae: 0.3166 - mse: 0.1806 - val_loss: 0.0865 - val_mae: 0.2865 - val_mse: 0.1396 - learning_rate: 5.0000e-04
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1147 - mae: 0.3327 - mse: 0.1987 - val_loss: 0.0758 - val_mae: 0.2580 - val_mse: 0.1177 - learning_rate: 5.0000e-04
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1056 - mae: 0.3106 - mse: 0.1806 - val_loss: 0.0759 - val_mae: 0.2557 - val_mse: 0.1201 - learning_rate: 5.0000e-04
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0992 - mae: 0.3071 - mse: 0.1682 - val_loss: 0.0740 - val_mae: 0.2461 - val_mse: 0.1162 - learning_rate: 5.0000e-04
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1023 - mae: 0.3109 - mse: 0.1749 - val_loss: 0.0889 - val_mae: 0.2921 - val_mse: 0.1498 - learning_rate: 5.0000e-04
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1048 - mae: 0.3191 - mse: 0.1819 - val_loss: 0.0815 - val_mae: 0.2808 - val_mse: 0.1328 - learning_rate: 5.0000e-04
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1076 - mae: 0.3246 - mse: 0.1873 - val_loss: 0.0852 - val_mae: 0.2823 - val_mse: 0.1399 - learning_rate: 5.0000e-04
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1080 - mae: 0.3215 - mse: 0.1876 - val_loss: 0.0897 - val_mae: 0.2875 - val_mse: 0.1479 - learning_rate: 5.0000e-04
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1093 - mae: 0.3299 - mse: 0.1898 - val_loss: 0.0837 - val_mae: 0.2923 - val_mse: 0.1390 - learning_rate: 5.0000e-04
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1056 - mae: 0.3222 - mse: 0.1836 - val_loss: 0.0775 - val_mae: 0.2689 - val_mse: 0.1228 - learning_rate: 5.0000e-04
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1103 - mae: 0.3255 - mse: 0.1903 - val_loss: 0.0815 - val_mae: 0.2685 - val_mse: 0.1332 - learning_rate: 5.0000e-04
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1100 - mae: 0.3261 - mse: 0.1917 - val_loss: 0.0771 - val_mae: 0.2570 - val_mse: 0.1268 - learning_rate: 5.0000e-04
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0983 - mae: 0.3040 - mse: 0.1706 - val_loss: 0.0788 - val_mae: 0.2611 - val_mse: 0.1289 - learning_rate: 5.0000e-04
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1000 - mae: 0.3081 - mse: 0.1733 - val_loss: 0.0735 - val_mae: 0.2671 - val_mse: 0.1202 - learning_rate: 5.0000e-04
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1109 - mae: 0.3343 - mse: 0.1952 - val_loss: 0.0926 - val_mae: 0.2780 - val_mse: 0.1550 - learning_rate: 5.0000e-04
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1065 - mae: 0.3167 - mse: 0.1820 - val_loss: 0.0806 - val_mae: 0.2650 - val_mse: 0.1309 - learning_rate: 5.0000e-04
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1096 - mae: 0.3161 - mse: 0.1909 - val_loss: 0.0858 - val_mae: 0.2731 - val_mse: 0.1399 - learning_rate: 5.0000e-04
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1000 - mae: 0.3115 - mse: 0.1698 - val_loss: 0.0783 - val_mae: 0.2661 - val_mse: 0.1278 - learning_rate: 5.0000e-04
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1001 - mae: 0.3078 - mse: 0.1720 - val_loss: 0.0750 - val_mae: 0.2579 - val_mse: 0.1212 - learning_rate: 5.0000e-04
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0980 - mae: 0.3075 - mse: 0.1686 - val_loss: 0.0772 - val_mae: 0.2723 - val_mse: 0.1247 - learning_rate: 5.0000e-04
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1029 - mae: 0.3116 - mse: 0.1766 - val_loss: 0.0846 - val_mae: 0.2730 - val_mse: 0.1396 - learning_rate: 5.0000e-04
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0964 - mae: 0.3028 - mse: 0.1646 - val_loss: 0.0735 - val_mae: 0.2530 - val_mse: 0.1202 - learning_rate: 5.0000e-04
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0957 - mae: 0.3064 - mse: 0.1646 - val_loss: 0.0793 - val_mae: 0.2691 - val_mse: 0.1314 - learning_rate: 5.0000e-04
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0975 - mae: 0.3050 - mse: 0.1703 - val_loss: 0.0737 - val_mae: 0.2578 - val_mse: 0.1200 - learning_rate: 5.0000e-04
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0963 - mae: 0.3032 - mse: 0.1658 - val_loss: 0.0937 - val_mae: 0.3032 - val_mse: 0.1606 - learning_rate: 5.0000e-04
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0970 - mae: 0.3020 - mse: 0.1662 - val_loss: 0.0755 - val_mae: 0.2674 - val_mse: 0.1215 - learning_rate: 5.0000e-04
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0968 - mae: 0.3041 - mse: 0.1652 - val_loss: 0.0709 - val_mae: 0.2428 - val_mse: 0.1151 - learning_rate: 5.0000e-04
# Epoch 45/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1000 - mae: 0.3120 - mse: 0.1745 - val_loss: 0.0793 - val_mae: 0.2666 - val_mse: 0.1275 - learning_rate: 5.0000e-04
# Epoch 46/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1054 - mae: 0.3220 - mse: 0.1824 - val_loss: 0.1033 - val_mae: 0.3064 - val_mse: 0.1742 - learning_rate: 5.0000e-04
# Epoch 47/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0968 - mae: 0.2992 - mse: 0.1623 - val_loss: 0.0758 - val_mae: 0.2603 - val_mse: 0.1211 - learning_rate: 5.0000e-04
# Epoch 48/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0975 - mae: 0.3045 - mse: 0.1669 - val_loss: 0.0792 - val_mae: 0.2661 - val_mse: 0.1290 - learning_rate: 5.0000e-04
# Epoch 49/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1007 - mae: 0.3059 - mse: 0.1751 - val_loss: 0.0751 - val_mae: 0.2620 - val_mse: 0.1211 - learning_rate: 5.0000e-04
# Epoch 50/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0967 - mae: 0.3058 - mse: 0.1672 - val_loss: 0.0840 - val_mae: 0.2634 - val_mse: 0.1395 - learning_rate: 5.0000e-04
# Epoch 51/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1038 - mae: 0.3172 - mse: 0.1810 - val_loss: 0.0714 - val_mae: 0.2529 - val_mse: 0.1162 - learning_rate: 5.0000e-04
# Epoch 52/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0953 - mae: 0.3029 - mse: 0.1647 - val_loss: 0.0783 - val_mae: 0.2637 - val_mse: 0.1303 - learning_rate: 5.0000e-04
# Epoch 53/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1037 - mae: 0.3200 - mse: 0.1827 - val_loss: 0.0655 - val_mae: 0.2533 - val_mse: 0.1061 - learning_rate: 5.0000e-04
# Epoch 54/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1006 - mae: 0.3206 - mse: 0.1773 - val_loss: 0.0892 - val_mae: 0.2944 - val_mse: 0.1530 - learning_rate: 5.0000e-04
# Epoch 55/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1043 - mae: 0.3235 - mse: 0.1846 - val_loss: 0.0809 - val_mae: 0.2738 - val_mse: 0.1366 - learning_rate: 5.0000e-04
# Epoch 56/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0997 - mae: 0.3065 - mse: 0.1757 - val_loss: 0.1072 - val_mae: 0.3355 - val_mse: 0.1886 - learning_rate: 5.0000e-04
# Epoch 57/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0984 - mae: 0.3069 - mse: 0.1694 - val_loss: 0.0870 - val_mae: 0.2715 - val_mse: 0.1440 - learning_rate: 5.0000e-04
# Epoch 58/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1006 - mae: 0.3090 - mse: 0.1734 - val_loss: 0.0782 - val_mae: 0.2624 - val_mse: 0.1281 - learning_rate: 5.0000e-04
# Epoch 59/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0973 - mae: 0.3045 - mse: 0.1689 - val_loss: 0.0838 - val_mae: 0.2707 - val_mse: 0.1397 - learning_rate: 5.0000e-04
# Epoch 60/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1035 - mae: 0.3148 - mse: 0.1810 - val_loss: 0.0925 - val_mae: 0.3021 - val_mse: 0.1581 - learning_rate: 5.0000e-04
# Epoch 61/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1008 - mae: 0.3089 - mse: 0.1755 - val_loss: 0.0840 - val_mae: 0.2906 - val_mse: 0.1421 - learning_rate: 5.0000e-04
# Epoch 62/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0962 - mae: 0.3101 - mse: 0.1665 - val_loss: 0.0808 - val_mae: 0.2934 - val_mse: 0.1365 - learning_rate: 5.0000e-04
# Epoch 63/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0978 - mae: 0.3030 - mse: 0.1712 - val_loss: 0.0785 - val_mae: 0.2768 - val_mse: 0.1322 - learning_rate: 5.0000e-04
# Epoch 64/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1002 - mae: 0.3096 - mse: 0.1758 - val_loss: 0.0788 - val_mae: 0.2632 - val_mse: 0.1314 - learning_rate: 5.0000e-04
# Epoch 65/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1016 - mae: 0.3143 - mse: 0.1807 - val_loss: 0.0722 - val_mae: 0.2500 - val_mse: 0.1181 - learning_rate: 5.0000e-04
# Epoch 66/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1009 - mae: 0.3128 - mse: 0.1762 - val_loss: 0.0824 - val_mae: 0.2731 - val_mse: 0.1386 - learning_rate: 5.0000e-04
# Epoch 67/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1000 - mae: 0.3129 - mse: 0.1739 - val_loss: 0.0756 - val_mae: 0.2516 - val_mse: 0.1232 - learning_rate: 5.0000e-04
# Epoch 68/100
#  95/100 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1152 - mae: 0.3388 - mse: 0.2065
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1144 - mae: 0.3374 - mse: 0.2048 - val_loss: 0.0786 - val_mae: 0.2751 - val_mse: 0.1327 - learning_rate: 5.0000e-04
# Epoch 69/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0929 - mae: 0.3019 - mse: 0.1642 - val_loss: 0.0783 - val_mae: 0.2895 - val_mse: 0.1396 - learning_rate: 2.5000e-04
# Epoch 70/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0888 - mae: 0.2918 - mse: 0.1607 - val_loss: 0.0747 - val_mae: 0.2851 - val_mse: 0.1325 - learning_rate: 2.5000e-04
# Epoch 71/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0953 - mae: 0.3144 - mse: 0.1745 - val_loss: 0.0696 - val_mae: 0.2483 - val_mse: 0.1218 - learning_rate: 2.5000e-04
# Epoch 72/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0898 - mae: 0.2975 - mse: 0.1637 - val_loss: 0.0702 - val_mae: 0.2564 - val_mse: 0.1227 - learning_rate: 2.5000e-04
# Epoch 73/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0835 - mae: 0.2865 - mse: 0.1501 - val_loss: 0.0630 - val_mae: 0.2375 - val_mse: 0.1086 - learning_rate: 2.5000e-04
# Epoch 74/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0912 - mae: 0.2999 - mse: 0.1664 - val_loss: 0.0676 - val_mae: 0.2508 - val_mse: 0.1185 - learning_rate: 2.5000e-04
# Epoch 75/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0955 - mae: 0.3083 - mse: 0.1764 - val_loss: 0.0700 - val_mae: 0.2511 - val_mse: 0.1222 - learning_rate: 2.5000e-04
# Epoch 76/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0918 - mae: 0.2993 - mse: 0.1685 - val_loss: 0.0688 - val_mae: 0.2625 - val_mse: 0.1206 - learning_rate: 2.5000e-04
# Epoch 77/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0949 - mae: 0.3044 - mse: 0.1744 - val_loss: 0.0702 - val_mae: 0.2606 - val_mse: 0.1246 - learning_rate: 2.5000e-04
# Epoch 78/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0911 - mae: 0.3051 - mse: 0.1670 - val_loss: 0.0784 - val_mae: 0.2795 - val_mse: 0.1407 - learning_rate: 2.5000e-04
# Epoch 79/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0850 - mae: 0.2901 - mse: 0.1550 - val_loss: 0.0687 - val_mae: 0.2511 - val_mse: 0.1212 - learning_rate: 2.5000e-04
# Epoch 80/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0891 - mae: 0.2982 - mse: 0.1633 - val_loss: 0.0668 - val_mae: 0.2480 - val_mse: 0.1170 - learning_rate: 2.5000e-04
# Epoch 81/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0900 - mae: 0.3016 - mse: 0.1648 - val_loss: 0.0722 - val_mae: 0.2705 - val_mse: 0.1290 - learning_rate: 2.5000e-04
# Epoch 82/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0922 - mae: 0.3038 - mse: 0.1698 - val_loss: 0.0649 - val_mae: 0.2523 - val_mse: 0.1131 - learning_rate: 2.5000e-04
# Epoch 83/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0925 - mae: 0.3016 - mse: 0.1694 - val_loss: 0.0701 - val_mae: 0.2436 - val_mse: 0.1224 - learning_rate: 2.5000e-04
# Epoch 84/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0929 - mae: 0.3016 - mse: 0.1697 - val_loss: 0.0708 - val_mae: 0.2696 - val_mse: 0.1247 - learning_rate: 2.5000e-04
# Epoch 85/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0958 - mae: 0.3113 - mse: 0.1761 - val_loss: 0.0905 - val_mae: 0.2958 - val_mse: 0.1639 - learning_rate: 2.5000e-04
# Epoch 86/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0886 - mae: 0.2953 - mse: 0.1610 - val_loss: 0.0665 - val_mae: 0.2530 - val_mse: 0.1152 - learning_rate: 2.5000e-04
# Epoch 87/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0938 - mae: 0.3080 - mse: 0.1721 - val_loss: 0.0637 - val_mae: 0.2530 - val_mse: 0.1118 - learning_rate: 2.5000e-04
# Epoch 88/100
#  97/100 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0899 - mae: 0.3010 - mse: 0.1648
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0898 - mae: 0.3008 - mse: 0.1645 - val_loss: 0.0750 - val_mae: 0.2690 - val_mse: 0.1341 - learning_rate: 2.5000e-04
# Epoch 89/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0951 - mae: 0.3081 - mse: 0.1784 - val_loss: 0.0763 - val_mae: 0.2839 - val_mse: 0.1400 - learning_rate: 1.2500e-04
# Epoch 90/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0936 - mae: 0.3083 - mse: 0.1762 - val_loss: 0.0628 - val_mae: 0.2538 - val_mse: 0.1137 - learning_rate: 1.2500e-04
# Epoch 91/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0834 - mae: 0.2880 - mse: 0.1559 - val_loss: 0.0756 - val_mae: 0.2816 - val_mse: 0.1401 - learning_rate: 1.2500e-04
# Epoch 92/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0836 - mae: 0.2913 - mse: 0.1569 - val_loss: 0.0586 - val_mae: 0.2407 - val_mse: 0.1066 - learning_rate: 1.2500e-04
# Epoch 93/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0929 - mae: 0.3077 - mse: 0.1782 - val_loss: 0.0790 - val_mae: 0.2887 - val_mse: 0.1485 - learning_rate: 1.2500e-04
# Epoch 94/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0866 - mae: 0.2980 - mse: 0.1639 - val_loss: 0.0646 - val_mae: 0.2441 - val_mse: 0.1186 - learning_rate: 1.2500e-04
# Epoch 95/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0807 - mae: 0.2843 - mse: 0.1514 - val_loss: 0.0680 - val_mae: 0.2580 - val_mse: 0.1270 - learning_rate: 1.2500e-04
# Epoch 96/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0873 - mae: 0.3004 - mse: 0.1653 - val_loss: 0.0601 - val_mae: 0.2455 - val_mse: 0.1102 - learning_rate: 1.2500e-04
# Epoch 97/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0867 - mae: 0.2979 - mse: 0.1645 - val_loss: 0.0605 - val_mae: 0.2394 - val_mse: 0.1108 - learning_rate: 1.2500e-04
# Epoch 98/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0833 - mae: 0.2902 - mse: 0.1578 - val_loss: 0.0632 - val_mae: 0.2511 - val_mse: 0.1164 - learning_rate: 1.2500e-04
# Epoch 99/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0828 - mae: 0.2885 - mse: 0.1566 - val_loss: 0.0638 - val_mae: 0.2527 - val_mse: 0.1175 - learning_rate: 1.2500e-04
# Epoch 100/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0853 - mae: 0.2970 - mse: 0.1613 - val_loss: 0.0625 - val_mae: 0.2582 - val_mse: 0.1150 - learning_rate: 1.2500e-04

# %% [markdown]
# # 5. Visual assessment of the model

# %%
mae = history.history['mae']
val_mae = history.history['val_mae']
loss = history.history['loss']
val_loss = history.history['val_loss']
history.history['val_mae']
epochs_range = range(len(history.history['loss']))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, mae, label='Training Mse')
plt.plot(epochs_range, val_mae, label='Validation Mse')
plt.legend(loc='lower right')
plt.title('Training and Validation Mse')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %%
x_val = x.values[train_size:] 
y_val = y.values[train_size:]



data_pred = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch)


predictions = model.predict(data_pred)


df_results = pd.DataFrame({
    'final_math_score_val': y_val,
    'predicted_score': predictions.flatten()
})

df_results['predicted_score_denorm'] = df_results['predicted_score'] * target_std + target_mean
df_results['final_math_score_val_denorm'] = df_results['final_math_score_val'] * target_std + target_mean


df_results.head(10)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#    final_math_score_val  predicted_score  predicted_score_denorm  \
# 0             -0.763267        -0.691408               79.076302
# 1              0.023958         0.186308               89.779816
# 2              1.024389         0.952295               99.120834
# 3              0.474972         0.937923               98.945564
# 4             -0.533660        -0.377678               82.902161
# 5             -0.369655        -0.091160               86.396172
# 6             -0.427056        -0.333447               83.441536
# 7              0.335567        -0.160001               85.556671
# 8             -0.861670        -0.587828               80.339432
# 9              0.556975         0.587643               94.673996
#
#    final_math_score_val_denorm
# 0                    78.199997
# 1                    87.800003
# 2                   100.000000
# 3                    93.300003
# 4                    81.000000
# 5                    83.000000
# 6                    82.300003
# 7                    91.599998
# 8                    77.000000
# 9                    94.300003

# %%
df_sample = df_results.head(50)

n = len(df_sample)
indices = np.arange(n)
width = 0.4

plt.figure(figsize=(12, 6))
plt.bar(indices - width/2, df_sample['final_math_score_val_denorm'], width=width, label='Actual Score', color='orange')
plt.bar(indices + width/2, df_sample['predicted_score_denorm'], width=width, label='Predicted Score', color='blue')

plt.title('Predicted vs Actual Math Scores (First 20 Samples)')
plt.xlabel('Sample Index')
plt.ylabel('Score')
plt.xticks(indices)  # чтобы были видны индексы по оси X
plt.legend()
plt.grid(True, axis='y')
plt.tight_layout()

plt.show()

# %% [markdown]
# # 6. Prediction based on test data and generation of the final response

# %%
#сsv с ответами
test = pd.read_csv('E:\\Alex\\Python_Files\\KBTU_Test\\test.csv')
test['gender'] = test['gender'].map(gen)
test['parental_education'] = test['parental_education'].map(edu)
test['school_type'] = test['school_type'].map(school)
test_students = test['student_id']
test = test.drop(columns='student_id')



#нормализация
test_n = (test - mean[:-1].numpy()) / std[:-1].numpy()

pred = model.predict(test_n)

#денормализация
pred_dn = pred * target_std + target_mean

test['predicted_math_score'] = pred_dn
test['student_id'] = test_students
test[['student_id', 'predicted_math_score']].to_csv('E:\\Alex\\Github\\my_projects\\test\\answer.csv', index=False)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
ans = pd.read_csv('E:\\Alex\\Github\\my_projects\\test\\answer.csv')
ans.head(10)
#----------------------
# Out:
#    student_id  predicted_math_score
# 0        5001              92.04616
# 1        5002              72.46287
# 2        5003              86.00399
# 3        5004              74.62029
# 4        5005              99.40968
# 5        5006              90.18101
# 6        5007              89.33683
# 7        5008              97.47979
# 8        5009              76.79981
# 9        5010              91.58592
